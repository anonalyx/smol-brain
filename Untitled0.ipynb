# %%
import os
import openai
import requests
import json

# %%
openai.api_key = "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"
openai.Model.list()
# Out:
# <OpenAIObject list at 0x7fad271746d0> JSON: {
#   "data": [
#     {
#       "created": 1649358449,
#       "id": "babbage",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
#           "allow_fine_tuning": false,
#           "allow_logprobs": true,
#           "allow_sampling": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "created": 1669085501,
#           "group": null,
#           "id": "modelperm-49FUp5v084tBB49tC4z8LPH5",
#           "is_blocking": false,
#           "object": "model_permission",
#           "organization": "*"
#         }
#       ],
#       "root": "babbage"
#     },
#     {
#       "created": 1649359874,
#       "id": "davinci",
#       "object": "model",
#       "owned_by": "openai",
#       "parent": null,
#       "permission": [
#         {
#           "allow_create_engine": false,
# ...

# %%
max([each.created for each in openai.Model.list().data])
# Out:
# 1677649963

# %%
help(requests.auth)
# Out:
# Help on module requests.auth in requests:
#
# NAME
#     requests.auth
#
# DESCRIPTION
#     requests.auth
#     ~~~~~~~~~~~~~
#
#     This module contains the authentication handlers for Requests.
#
# CLASSES
#     builtins.object
#         AuthBase
#             HTTPBasicAuth
#                 HTTPProxyAuth
#             HTTPDigestAuth
#
#     class AuthBase(builtins.object)
#      |  Base class that all auth implementations derive from
#      |
#      |  Methods defined here:
#      |
#      |  __call__(self, r)
#      |      Call self as a function.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class HTTPBasicAuth(AuthBase)
#      |  HTTPBasicAuth(username, password)
#      |
# ...

# %%
url = "https://api.openai.com/v1/completions"
headers = {
    "Authorization": "Bearer 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"
}
body = {
    "model": "text-davinci-003", "prompt": "Give me a quote of the day in the style of Albert Einstein, but attribute it to a famous serial killer", "temperature": 0, "max_tokens": 500
}
response = requests.post(url, headers=headers,json=body)

# %%
rep = response.json()

# %%
rep
# Out:
# {'id': 'cmpl-6qyLHm1S1jB2REGXTwesNquOK6e5X',
#  'object': 'text_completion',
#  'created': 1678083031,
#  'model': 'text-davinci-003',
#  'choices': [{'text': '\n\n"The definition of insanity is doing the same thing over and over again and expecting different results" - Ted Bundy',
#    'index': 0,
#    'logprobs': None,
#    'finish_reason': 'stop'}],
#  'usage': {'prompt_tokens': 22, 'completion_tokens': 24, 'total_tokens': 46}}

# %%
rep['choices']
# Out:
# [{'text': '\n\n"The only true wisdom is in knowing you know nothing" - Ted Bundy',
#   'index': 0,
#   'logprobs': None,
#   'finish_reason': 'stop'}]
